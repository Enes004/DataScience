# %%
dic = {
    "enes":100,
    "ali":50,
    "msaid":20,
}

dic.get("enes")
# Out:
# 100

# %%
mySet = {10,10,20,30,40,40,40,50}

# %%
mySet2 = {60,60,60,70}

# %%
mySet.union(mySet2)
# Out:
# {10, 20, 30, 40, 50, 60, 70}

# %%
myTuple = (1,2,"abcd",3.14)

# %%
#myTuple[1] = 56   !!!Immutability!!!  #ıt cant be change

# %%
myString = "ım learning phyton"

# %%
a = myString[4]
a
# Out:
# 'e'

# %%
b = myString[4:8]
b
# Out:
# 'earn'

# %%
word= "afyonkarahisarlilar"
word = list(word)
word.reverse()
word = str(word)
print(word)
# Out:
# ['r', 'a', 'l', 'i', 'l', 'r', 'a', 's', 'i', 'h', 'a', 'r', 'a', 'k', 'n', 'o', 'y', 'f', 'a']
