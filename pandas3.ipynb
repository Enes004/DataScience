# %%
import numpy as np
import pandas as pd

# %%
weather_df = pd.read_excel("6-weather.xlsx")

# %%
weather_df
# Out:
#    Istanbul  New York  Amsterdam  Paris
# 0        20        10         15     12
# 1        21        10         17     14
# 2        20        13         18     15
# 3        22        14         19     18
# 4        25        15         15     20
# 5        28        13         22     16
# 6        15        12         15     15
# 7        20        15         14     14
# 8        22        16         16     16

# %%
weather_df.head()
# Out:
#    Istanbul  New York  Amsterdam  Paris
# 0        20        10         15     12
# 1        21        10         17     14
# 2        20        13         18     15
# 3        22        14         19     18
# 4        25        15         15     20

# %%
weather_df.tail()
# Out:
#    Istanbul  New York  Amsterdam  Paris
# 4        25        15         15     20
# 5        28        13         22     16
# 6        15        12         15     15
# 7        20        15         14     14
# 8        22        16         16     16

# %%
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Istanbul   9 non-null      int64
#  1   New York   9 non-null      int64
#  2   Amsterdam  9 non-null      int64
#  3   Paris      9 non-null      int64
# dtypes: int64(4)
# memory usage: 420.0 bytes

# %%
weather_df.count()
# Out:
# Istanbul     9
# New York     9
# Amsterdam    9
# Paris        9
# dtype: int64

# %%
weather_df.isna()
# Out:
#    Istanbul  New York  Amsterdam  Paris
# 0     False     False      False  False
# 1     False     False      False  False
# 2     False     False      False  False
# 3     False     False      False  False
# 4     False     False      False  False
# 5     False     False      False  False
# 6     False     False      False  False
# 7     False     False      False  False
# 8     False     False      False  False

# %%
## Working with missing data

# %%
wna_df = pd.read_excel("6-weatherna (1).xlsx")

# %%
wna_df
# Out:
#    Istanbul  New York  Amsterdam  Paris
# 0      20.0      10.0       15.0   12.0
# 1      21.0      10.0        NaN   14.0
# 2       NaN      13.0       18.0   15.0
# 3      22.0      14.0       19.0   18.0
# 4      25.0      15.0       15.0   20.0
# 5      28.0       NaN       22.0    NaN
# 6      15.0      12.0       15.0   15.0
# 7      20.0      15.0       14.0    NaN
# 8      22.0      16.0       16.0    NaN

# %%
wna_df.isna()
# Out:
#    Istanbul  New York  Amsterdam  Paris
# 0     False     False      False  False
# 1     False     False       True  False
# 2      True     False      False  False
# 3     False     False      False  False
# 4     False     False      False  False
# 5     False      True      False   True
# 6     False     False      False  False
# 7     False     False      False   True
# 8     False     False      False   True

# %%
wna_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Istanbul   8 non-null      float64
#  1   New York   8 non-null      float64
#  2   Amsterdam  8 non-null      float64
#  3   Paris      6 non-null      float64
# dtypes: float64(4)
# memory usage: 420.0 bytes

# %%
wna_df.count()
# Out:
# Istanbul     8
# New York     8
# Amsterdam    8
# Paris        6
# dtype: int64

# %%
wna_df.describe()
# Out:
#         Istanbul   New York  Amsterdam      Paris
# count   8.000000   8.000000   8.000000   6.000000
# mean   21.625000  13.125000  16.750000  15.666667
# std     3.814914   2.295181   2.712405   2.875181
# min    15.000000  10.000000  14.000000  12.000000
# 25%    20.000000  11.500000  15.000000  14.250000
# 50%    21.500000  13.500000  15.500000  15.000000
# 75%    22.750000  15.000000  18.250000  17.250000
# max    28.000000  16.000000  22.000000  20.000000

# %%
wna_df["Paris"].count()
# Out:
# np.int64(6)

# %%
wna_df["Paris"].mean()
# Out:
# np.float64(15.666666666666666)

# %%
wna_df.dropna()
# Out:
#    Istanbul  New York  Amsterdam  Paris
# 0      20.0      10.0       15.0   12.0
# 3      22.0      14.0       19.0   18.0
# 4      25.0      15.0       15.0   20.0
# 6      15.0      12.0       15.0   15.0

# %%
wna_df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
wna_df.drop("Paris",axis=1)
# Out:
#    Istanbul  New York  Amsterdam
# 0      20.0      10.0       15.0
# 1      21.0      10.0        NaN
# 2       NaN      13.0       18.0
# 3      22.0      14.0       19.0
# 4      25.0      15.0       15.0
# 5      28.0       NaN       22.0
# 6      15.0      12.0       15.0
# 7      20.0      15.0       14.0
# 8      22.0      16.0       16.0

# %%
mean_data = wna_df.mean()
mean_data
# Out:
# Istanbul     21.625000
# New York     13.125000
# Amsterdam    16.750000
# Paris        15.666667
# dtype: float64

# %%
wna_df.fillna(mean_data)
# Out:
#    Istanbul  New York  Amsterdam      Paris
# 0    20.000    10.000      15.00  12.000000
# 1    21.000    10.000      16.75  14.000000
# 2    21.625    13.000      18.00  15.000000
# 3    22.000    14.000      19.00  18.000000
# 4    25.000    15.000      15.00  20.000000
# 5    28.000    13.125      22.00  15.666667
# 6    15.000    12.000      15.00  15.000000
# 7    20.000    15.000      14.00  15.666667
# 8    22.000    16.000      16.00  15.666667

# %%
wna_df.max()
# Out:
# Istanbul     28.0
# New York     16.0
# Amsterdam    22.0
# Paris        20.0
# dtype: float64

# %%
wna_df.min()
# Out:
# Istanbul     15.0
# New York     10.0
# Amsterdam    14.0
# Paris        12.0
# dtype: float64

# %%
##groupby

# %%
df = pd.read_csv("6-employee.csv")

# %%
df
# Out:
#    Department Employee  Salary  Experience           City
# 0   Marketing    Emp_1   53483           1       New York
# 1       Sales    Emp_2   78555           8         Austin
# 2     Finance    Emp_3   47159           3         Austin
# 3       Sales    Emp_4  110077           3  San Francisco
# 4       Sales    Emp_5   65920           1       New York
# 5          IT    Emp_6   97121          11        Chicago
# 6     Finance    Emp_7   99479           5        Chicago
# 7     Finance    Emp_8  119475          10       New York
# 8     Finance    Emp_9   49457           7        Chicago
# 9       Sales   Emp_10   96557          10        Chicago
# 10  Marketing   Emp_11  107189           9       New York
# 11    Finance   Emp_12  108953          12         Austin
# 12      Sales   Emp_13   82995           7       New York
# 13         IT   Emp_14   70757           9         Austin
# 14  Marketing   Emp_15   39692           8        Chicago
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Department  50 non-null     object
#  1   Employee    50 non-null     object
#  2   Salary      50 non-null     int64
#  3   Experience  50 non-null     int64
#  4   City        50 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 2.1+ KB

# %%
df.describe()
# Out:
#               Salary  Experience
# count      50.000000   50.000000
# mean    78344.500000    7.060000
# std     27817.603904    3.966235
# min     31016.000000    1.000000
# 25%     53687.250000    3.000000
# 50%     78769.500000    7.000000
# 75%    100778.000000   10.000000
# max    119812.000000   14.000000

# %%
df.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df.mean()
#
# File ~/myenv/lib/python3.12/site-packages/pandas/core/frame.py:11720, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11712 @doc(make_doc("mean", ndim=2))
#   11713 def mean(
#   11714     self,
#    (...)  11718     **kwargs,
#   11719 ):
# > 11720     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11721     if isinstance(result, Series):
#   11722         result = result.__finalize__(self, method="mean")
#
# File ~/myenv/lib/python3.12/site-packages/pandas/core/generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12478 def mean(
#   12479     self,
#   12480     axis: Axis | None = 0,
#    (...)  12483     **kwargs,
#   12484 ) -> Series | float:
# > 12485     return self._stat_function(
# ...

# %%
df[["Salary","Experience"]].mean()
# Out:
# Salary        78344.50
# Experience        7.06
# dtype: float64

# %%
df[df["Experience"]>10]
# Out:
#    Department Employee  Salary  Experience           City
# 5          IT    Emp_6   97121          11        Chicago
# 11    Finance   Emp_12  108953          12         Austin
# 15         IT   Emp_16   75758          12        Chicago
# 20         IT   Emp_21   62606          14  San Francisco
# 24         HR   Emp_25  119789          12       New York
# 27         IT   Emp_28   53247          11         Austin
# 32  Marketing   Emp_33  116807          14  San Francisco
# 38         HR   Emp_39   68044          14       New York
# 40  Marketing   Emp_41   91228          11  San Francisco
# 44         IT   Emp_45   92592          12        Chicago
# 45         HR   Emp_46   97563          13  San Francisco

# %%
df[df["Experience"]>10].count()
# Out:
# Department    11
# Employee      11
# Salary        11
# Experience    11
# City          11
# dtype: int64

# %%
df_dep = df.groupby("Department")

# %%
df_dep.count()
# Out:
#             Employee  Salary  Experience  City
# Department
# Finance           10      10          10    10
# HR                 7       7           7     7
# IT                10      10          10    10
# Marketing         13      13          13    13
# Sales             10      10          10    10

# %%
df_dep.describe()
# Out:
#            Salary                                                          \
#             count          mean           std      min       25%      50%
# Department
# Finance      10.0  90552.700000  27228.231832  47159.0  73222.00  96591.5
# HR            7.0  76182.571429  31647.523983  31016.0  55114.50  78984.0
# IT           10.0  63381.600000  24272.881041  32568.0  39755.25  66681.5
# Marketing    13.0  79555.000000  28431.207129  39268.0  54300.00  70774.0
# Sales        10.0  81038.900000  26623.181534  38571.0  68987.50  80775.0
#
#                                 Experience                                \
#                   75%       max      count      mean       std  min  25%
# Department
# Finance     111836.75  119812.0       10.0  6.500000  3.566822  1.0  3.5
# HR           96630.00  119789.0        7.0  8.714286  4.572173  3.0  5.0
# IT           79850.00   97121.0       10.0  9.000000  4.163332  1.0  7.5
# ...

# %%
df_dep["Salary"].mean()
# Out:
# Department
# Finance      90552.700000
# HR           76182.571429
# IT           63381.600000
# Marketing    79555.000000
# Sales        81038.900000
# Name: Salary, dtype: float64

# %%
df_city = df.groupby("City")

# %%
df.city["Salary"].mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_6456/2335108156.py in ?()
# ----> 1 df.city["Salary"].count()
#
# ~/myenv/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'city'
