# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = np.array([1,2,3,4,43,35,34,16,12,31,25,14,13,17,60])

# %%
plt.figure(figsize=(6,6))
sns.boxplot(y=data)
plt.title("Box Plot")
plt.grid(True)
plt.show()
